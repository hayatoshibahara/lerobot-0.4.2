# %% [markdown]
# # 3Dプリンターでの印刷手順

# %% [markdown]
# ![](asset/83.jpg)

# %% [markdown]
# ![](asset/84.jpg)

# %% [markdown]
# ![](asset/85.jpg)

# %% [markdown]
# ![](asset/86.jpg)

# %% [markdown]
# ![](asset/87.jpg)

# %% [markdown]
# ![](asset/88.jpg)

# %% [markdown]
# ![](asset/89.jpg)

# %% [markdown]
# ![](asset/90.jpg)

# %% [markdown]
# ![](asset/91.jpg)

# %% [markdown]
# ![](asset/92.jpg)

# %% [markdown]
# ![](asset/93.jpg)
